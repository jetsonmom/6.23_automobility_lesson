# %% [markdown]
# <a href="https://colab.research.google.com/github/jetsonmom/6.23_automobility_lesson/blob/main/%EC%88%98%EC%97%85_%EC%88%98%EC%97%85_beginner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📝 [1] 첫 실습: 출력하기
# ▶ print() 함수로 인사말을 출력해보세요.
print("안녕하세요! 코랩에서 파이썬을 배워봅시다 😊")

# %%
# 📝 [2] 변수 사용해보기
# ▶ 숫자형 변수와 문자열 변수를 사용해 봅니다.
name = "홍길동"
age = 16
print(name, "님의 나이는", age, "세입니다.")

# %%
# 📝 [3] 리스트(List) 사용
# ▶ 여러 과일 이름을 저장하고 출력해봅니다.
fruits = ["사과", "바나나", "포도", "귤"]
print("과일 목록:", fruits)

# %%
# 📝 [4] 반복문 for
# ▶ 리스트에 있는 과일을 하나씩 출력해 봅니다.
for fruit in fruits:
    print("맛있는 과일:", fruit)

# %%
# 📝 [5] 조건문 if
# ▶ 나이에 따라 출력 문구를 다르게 해봅니다.
if age >= 18:
    print("성인입니다.")
else:
    print("청소년입니다.")

# %%
# 📝 [6] 간단한 입력 받기 (주의: 코랩에서는 실행시마다 입력칸이 나타납니다)
# ▶ 사용자 이름을 입력받아 인사합니다.
name = input("이름을 입력하세요: ")
print("반가워요,", name, "님!")

# %%
# 📝 [7] 시각화 예제 - matplotlib
# ▶ 간단한 선 그래프 그려보기
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

plt.plot(x, y)
plt.title("간단한 선 그래프")
plt.xlabel("시간")
plt.ylabel("값")
plt.grid(True)
plt.show()

# %%
# 사용자에게 숫자를 입력받아 짝수인지 홀수인지 출력하는 프로그램을 만드세요.

num = int(input("숫자를 입력하세요: "))

# 여기에 if문을 작성하세요

# %%
# 점수를 입력받아 다음 기준에 따라 학점을 출력하세요.
# 90 이상: A, 80 이상: B, 70 이상: C, 60 이상: D, 나머지: F

score = int(input("점수를 입력하세요: "))

# 여기에 if-elif-else 문을 작성하세요

# %%
# 저장된 사용자 이름과 비밀번호를 이용해 로그인 확인 프로그램을 만드세요.
# 이름이 일치하고 비밀번호도 일치하면 "로그인 성공!" 출력
# 하나라도 틀리면 "로그인 실패!" 출력

user_id = "student"
user_pw = "pass123"

# 입력받기
input_id = input("아이디를 입력하세요: ")
input_pw = input("비밀번호를 입력하세요: ")

# 여기에 조건문을 작성하세요

# %%
# 키(cm)를 입력받아 140cm 이상이면 "탑승 가능", 아니면 "탑승 불가" 출력
# 그리고, 120cm 미만이면 "탑승 절대 불가"라고 출력하도록 조건을 추가하세요.

height = int(input("키를 입력하세요 (cm): "))

# 조건을 if/elif/else로 나누어 작성하세요

# %%
# 두 개의 숫자를 입력받아 더 큰 수를 출력하세요.
# 두 수가 같으면 "두 수는 같습니다"라고 출력하세요.

a = int(input("첫 번째 수: "))
b = int(input("두 번째 수: "))

# if/elif/else로 조건을 나누어 작성하세요

# %%
# 1부터 5까지 숫자를 한 줄씩 출력해보세요.

for i in range(1, 6):
    print(i)

# %%
# "안녕하세요!"를 3번 반복 출력해보세요.

for i in range(3):
    print("안녕하세요!")

# %%
# fruits 리스트의 각 과일을 한 줄씩 출력하세요.

fruits = ['사과', '바나나', '포도', '귤']

for fruit in fruits:
    print(fruit)

# %%
# 1부터 10까지 중에서 짝수만 출력해보세요.

for i in range(1, 11):
    if i % 2 == 0:
        print(i)

# %%
# 구구단 5단을 다음과 같이 출력하세요:
# 5 x 1 = 5
# 5 x 2 = 10
# ...

for i in range(1, 10):
    print("5 x", i, "=", 5 * i)

# %%
# numbers 리스트 안의 숫자들을 모두 더한 합계를 출력하세요.

numbers = [3, 7, 1, 9, 5]
total = 0

for num in numbers:
    total += num

print("합계:", total)

# %%
# 사용자가 입력한 문자열을 한 글자씩 줄바꿈하여 출력하세요.

text = input("문장을 입력하세요: ")

for char in text:
    print(char)

# %%
# 별(*)을 한 줄에 5개 가로로 출력하세요.

for i in range(5):
    print("*", end="")

# %%
# 리스트를 역순으로 출력하세요.

nums = [1, 2, 3, 4, 5]

for i in reversed(nums):
    print(i)

# %%
# 구구단 2단부터 4단까지 출력해보세요.
# 단과 곱하는 수를 중첩된 for문으로 표현하세요.

for dan in range(2, 5):
    for i in range(1, 10):
        print(f"{dan} x {i} = {dan * i}")
    print("------")
